# %%
# %%writefile modul_bangun_ruang.py
import math

def kubus(sisi):
    hasil = math.pow(sisi, 3)
    return hasil

def balok(p, l, t):
    hasil = p*l*t
    return hasil

def prisma(a,ts, tp):
    la = a*ts/2
    hasil = la*tp
    return hasil

def tabung(r, t):
    return math.pi*r*r*t

def kerucut(r, t):
    return (1/3)*math.pi*r*r*t
# Out:
# Overwriting modul_bangun_ruang.py

# %%
# %%writefile modul_bangun_datar.py
import math

def persegi(s):
    return s*s

def persegi_panjang(p, l):
    return p*l

def segitiga(a, t):
    return 0.5*a*t

def lingkaran(r):
    return math.pi*r*r

def jajargenjang(a, t):
    return a*t
# Out:
# Overwriting modul_bangun_datar.py

# %%
import modul_bangun_ruang as br
import modul_bangun_datar as bd

print("~~ BANGUN RUANG~~ ")
print(f"Volum Kubus dengan sisi 3 adalah {br.kubus(3)}")
print(f"Volum balok adalah {br.balok(4, 5, 2)}")
print(f"Volum Prisma Segitiga adalah {br.prisma(5,4,5)}")
print(f"Volum Tabung dengan jari-jari 7 dan tinggi 10 adalah {br.tabung(7, 10)}")
print(f"Volum Kerucut dengan jari-jari 5 dan tinggi 12 adalah {br.kerucut(5, 12)}")

print(" ~~BANGUN DATAR ~~")
print(f"Luas Persegi dengan sisi 4 adalah {bd.persegi(4)}")
print(f"Luas Persegi Panjang dengan panjang 6 dan lebar 8 adalah {bd.persegi_panjang(6, 8)}")
print(f"Luas Segitiga dengan alas 10 dan tinggi 5 adalah {bd.segitiga(10, 5)}")
print(f"Luas Lingkaran dengan jari-jari 7 adalah {bd.lingkaran(7)}")
print(f"Luas JajarGenjang dengan alas 9 dan tinggi 4 adalah {bd.jajargenjang(9, 4)}")
# Out:
# ~~ BANGUN RUANG~~
# Volum Kubus dengan sisi 3 adalah 27.0
# Volum balok adalah 40
# Volum Prisma Segitiga adalah 50.0
# Volum Tabung dengan jari-jari 7 dan tinggi 10 adalah 1539.3804002589986
# Volum Kerucut dengan jari-jari 5 dan tinggi 12 adalah 314.15926535897927
#  ~~BANGUN DATAR ~~
# Luas Persegi dengan sisi 4 adalah 16
# Luas Persegi Panjang dengan panjang 6 dan lebar 8 adalah 48
# Luas Segitiga dengan alas 10 dan tinggi 5 adalah 25.0
# Luas Lingkaran dengan jari-jari 7 adalah 153.93804002589985
# Luas JajarGenjang dengan alas 9 dan tinggi 4 adalah 36
